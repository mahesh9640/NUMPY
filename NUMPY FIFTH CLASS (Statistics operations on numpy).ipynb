# %% [markdown]
# ### Statistics

# %% [raw]
# --->Statistics is the way to solve a problem by using the data.
#
# 1.Descriptive Statistics:
#     --->Describing the data.
#     --->We have different techniques and measures in descriptive stats to describe the data.
#     --->We want to explore the data
#
#     -->First Moment Business Decision:
#         1.Mean:
#             --->Average of the data.
#             --->Mean=(sum of all observations/Total number of observations)
#             --->Outliers means a datapoint which is not in a range.
#             --->Whenever we have outliers we better not use mean.
#             --->Here time is "order of n"
#
#
#         2.Medain:
#             --->Average of the data
#             --->When we have outliers present in the dataset then better to use median because medain is not influenced by the outliers
#             --->To find the median first sort the data in assceding order.
#             --->Odd no of data middle one.
#             --->Even no of data middle one + (mid+1)
#             SYNTAX: np.median(array_name)
#
#
#         3.Mode:Although this is not work on the numpy we will use (scipy)
#
#             DEFINATION OF MODE: ---> It will work on the categorical data.
#                                 ---> Mode means maximum ocuurance of the datapoints.
#                                 --->There can be multiple modes in the dataset we called it as multimodal dataset.
#                                 --->If we wanted to select any one of two its completely depends upon problem statement.
#                                 --->There are two types of data
#                 1.Numerical data
#                     --->It will contains the numerical value,
#                     --->Numerical data again classify into two types:
#                         a.Continous data: It is having continious real value.
#                             EX: weight,height etc
#                         b.discreate data: It will not contain fractional value.
#                             EX: Count of students etc.
#                     --->Mean and meadian will works on numerical data only
#
#                 2.Categorical data:
#                     --->It will specify the category.
#                     --->We cannot find out the mean and median for categorical data
#
#
#
#     --> Second Moment Business Decision:(Measures of the dispersion)
#         --->Dispersion means how the data points are varying .
#         1.Range:
#             --->max(array)
#             --->min(array)
#         2.Standared Deviation
#             --->It is square root of varaince
#                 SYNTAX: np.std(array_name)
#         3.Variance
#             --->How far each data point from the average
#                 SYNTAX:np.var(array_name)
# CUMSUM:
# [1,2,3,4,5]:[1,3,6,10,15]
# syntax: np.cumsum(array_name)
#
# PERCENTAILE:
#     [12---------N]
# --->50 Percentile: How many data points are there which is less than 50% percent value.
# --->Syntax: np.percentaile(Array_name,25)
#
# CORRELATION:
#         --->Relationship between the two features will justify the two features.
#         --->rho:1--->string relation
#         --->  -1---->weak relation
#         --->   0---->No relation
#                             SYNTAX: np.corrcoef(a1,a1)
#
#
# 2.Inferential Statistics:
#     --->We are making some conclusion on the sample and infereing about the population.
